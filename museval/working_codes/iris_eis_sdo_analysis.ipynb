# %%
import museval
from museval.utils import save_eis_iris_dates
import os
import matplotlib.pyplot as plt
import astropy.units as u
from astropy.coordinates import SkyCoord
# from astropy.time import Time
from astropy.visualization import ImageNormalize, SqrtStretch
import sunpy.coordinates  # NOQA
import sunpy.map
from sunpy.net import Fido
from sunpy.net import attrs as a
import eispac
import eispac.net
from eispac.net.attrs import FileType
import glob
import numpy as np
import pdb
from aiapy.psf import deconvolve, psf
from astropy.visualization import ImageNormalize, LogStretch, time_support
from tqdm import tqdm
import astropy.io.ascii as ascii
import pdb

# %%
urls = ['https://www.lmsal.com/hek/hcr?cmd=search-events-corr&outputformat=json&startTime=2017-01-01T00:00&stopTime=2017-12-31T23:55&instrument=IRIS&minhpcRadius=-500&maxhpcRadius=500&hideMostLimbScans=true&obsDesc=HOP+307+&optionalcorr=SOT&optionalcorr=SOTSP&optionalcorr=XRT&requiredcorr=EIS',
        'https://www.lmsal.com/hek/hcr?cmd=search-events-corr&outputformat=json&startTime=2018-01-01T00:00&stopTime=2018-12-31T23:55&instrument=IRIS&minhpcRadius=-500&maxhpcRadius=500&hideMostLimbScans=true&obsDesc=HOP+307+&optionalcorr=SOT&optionalcorr=SOTSP&optionalcorr=XRT&requiredcorr=EIS',
        'https://www.lmsal.com/hek/hcr?cmd=search-events-corr&outputformat=json&startTime=2019-01-01T00:00&stopTime=2019-12-31T23:55&instrument=IRIS&minhpcRadius=-500&maxhpcRadius=500&hideMostLimbScans=true&obsDesc=HOP+307+&optionalcorr=SOT&optionalcorr=SOTSP&optionalcorr=XRT&requiredcorr=EIS',
        'https://www.lmsal.com/hek/hcr?cmd=search-events-corr&outputformat=json&startTime=2020-01-01T00:00&stopTime=2020-12-31T23:55&instrument=IRIS&minhpcRadius=-500&maxhpcRadius=500&hideMostLimbScans=true&obsDesc=HOP+307+&optionalcorr=SOT&optionalcorr=SOTSP&optionalcorr=XRT&requiredcorr=EIS',
]
text_files_path = '/Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/'
for ii, url in tqdm(enumerate(urls)):
    save_eis_iris_dates([url], f"{text_files_path}HOP_307_dates_{ii}.txt", alternate_only=True)
# Out:
# 0it [00:00, ?it/s]
# Fetching: https://www.lmsal.com/hek/hcr?cmd=search-events-corr&outputformat=json&startTime=2017-01-01T00:00&stopTime=2017-12-31T23:55&instrument=IRIS&minhpcRadius=-500&maxhpcRadius=500&hideMostLimbScans=true&obsDesc=HOP+307+&optionalcorr=SOT&optionalcorr=SOTSP&optionalcorr=XRT&requiredcorr=EIS
# 1it [00:10, 10.19s/it]
# Number of events in JSON: 67
# Saved 12 date ranges to /Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/HOP_307_dates_0.txt
# Fetching: https://www.lmsal.com/hek/hcr?cmd=search-events-corr&outputformat=json&startTime=2018-01-01T00:00&stopTime=2018-12-31T23:55&instrument=IRIS&minhpcRadius=-500&maxhpcRadius=500&hideMostLimbScans=true&obsDesc=HOP+307+&optionalcorr=SOT&optionalcorr=SOTSP&optionalcorr=XRT&requiredcorr=EIS
# 2it [00:20, 10.38s/it]
# Number of events in JSON: 71
# Saved 12 date ranges to /Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/HOP_307_dates_1.txt
# ...

# %%
os.environ['text_files_path'] = '/Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/'
os.environ['eis_data_path'] = '/Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/'
txt_files = glob.glob(os.path.join(os.environ['text_files_path'], "*.txt"))
txt_files = sorted(txt_files)
txt_files
# Out:
# ['/Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/HOP_307_dates_0.txt',
#  '/Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/HOP_307_dates_1.txt',
#  '/Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/HOP_307_dates_2.txt',
#  '/Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/HOP_307_dates_3.txt']

# %%
email ='sbose925@gmail.com'
for idx_txt, txt_file in enumerate(txt_files):
    print(f"Processing {txt_file}")
    obs_dates = ascii.read(txt_file)
# Out:
# Processing /Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/HOP_307_dates_0.txt
# Processing /Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/HOP_307_dates_1.txt
# Processing /Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/HOP_307_dates_2.txt
# Processing /Users/souvikb/MUSE_outputs/EIS_IRIS_QS_obs/Plage_datasets/HOP_307/HOP_307_dates_3.txt
